# %%
# %matplotlib inline
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Bar Graph

# %%
df = pd.read_csv('pokemon_alopez247.csv') 
df.head()
# Out:
#    Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
#
#    Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65  ...  Green       True    0.875     Monster        Grass
# 1      80  ...  Green       True    0.875     Monster        Grass
# 2     100  ...  Green       True    0.875     Monster        Grass
# 3      50  ...    Red       True    0.875     Monster       Dragon
# 4      65  ...    Red       True    0.875     Monster       Dragon
#
#    hasMegaEvolution Height_m Weight_kg  Catch_Rate      Body_Style
# 0             False     0.71       6.9          45       quadruped
# 1             False     0.99      13.0          45       quadruped
# 2              True     2.01     100.0          45       quadruped
# 3             False     0.61       8.5          45  bipedal_tailed
# 4             False     1.09      19.0          45  bipedal_tailed
#
# [5 rows x 23 columns]

# %%
from scipy.stats import itemfreq

type_1 = itemfreq(df.loc[:,'Type_1'])

type_1_grps = len(type_1)

type_1_names = type_1[:,0]

type_1_count = type_1[:,1]

print(type_1_grps)
print(type_1_count)
# Out:
# 18
# [63 28 24 36 17 25 47 3 23 66 30 23 93 28 47 41 22 105]
# C:\Users\malla\anaconda3\lib\site-packages\ipykernel_launcher.py:3: DeprecationWarning: `itemfreq` is deprecated!
# `itemfreq` is deprecated and will be removed in a future version. Use instead `np.unique(..., return_counts=True)`
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
type_1_grps = len(type_1)
type_1_grps = np.arange(type_1_grps)
bar_width = 0.5
plt.figure(figsize=(10,6))
plt.bar(type_1_grps,type_1_count,bar_width,alpha=0.5,color='g',label='Pokemon count respective to their Type_1')
plt.legend(loc='best')
#plt.xticks(type_1_grps + bar_width/2, type_1_names)
plt.xticks(type_1_grps,type_1_names,rotation=45)  # X-axis values - place type at values
plt.xlabel('Types')
plt.ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# #### Exercise

# %%
n_grps = np.arange(5)
bar_width = 0.4
men_sc = [20, 30, 10, 50, 90]
err_men_sc = [2, 3, 4, 5, 4]
women = [10, 123, 19, 60, 40]
err_women_sc = [1, 6, 2, 8, 7]

# %%
plt.figure(figsize=(10,6))
bar_width = 0.25
plt.bar(n_grps,men_sc,-0.25,color='b',alpha=0.5,yerr=err_men_sc,align='edge',label='Men')
plt.bar(n_grps+bar_width,women,-0.25,color='r',alpha=0.5,align='edge',label='Women')
plt.legend(loc='best')
plt.xlabel('Groups')
plt.ylabel('Score')
plt.xticks(n_grps,['A','B','C','D','E'])
# Out:
# ([<matplotlib.axis.XTick at 0x1af1f1b2f08>,
#   <matplotlib.axis.XTick at 0x1af1f1b25c8>,
#   <matplotlib.axis.XTick at 0x1af1f1b2188>,
#   <matplotlib.axis.XTick at 0x1af1f202b48>,
#   <matplotlib.axis.XTick at 0x1af1f207448>],
#  <a list of 5 Text xticklabel objects>)

# %% [markdown]
# ## Advanced Bar Graph

# %%
import random

# Creating 18 random colors range (0 - 1)
clrs = np.linspace( 0, 1, 18 )
random.shuffle(clrs)
# Creating final list of 18 random colors
colors = []
for i in range(0, 72, 4):
    idx = np.arange( 0, 18, 1 )
    random.shuffle(idx)
    r = clrs[idx[0]]
    g = clrs[idx[1]]
    b = clrs[idx[2]]
    a = clrs[idx[3]]
    colors.append([r, g, b, a])
    
plt.figure(figsize=(10,6))
bar_graph = plt.bar(type_1_grps, type_1_count, bar_width,
                 alpha = 0.5,   # tranparency factor
                 color = colors,label=type_1_names)   # color factor

plt.legend(bar_graph, 
           type_1_names,                    # List of group names
           bbox_to_anchor=(1.15, 1.015))   # Position of legend
 
plt.xticks(type_1_grps + bar_width/2, type_1_names,rotation=45)
plt.xlabel('Type')
plt.ylabel('Pokemon count')
plt.title('Number of Pokemon per Type_1')
plt.grid()
plt.ylim(0,130)
# Out:
# (0, 130)

# %% [markdown]
# ## Pie Chart

# %%
df.head()
# Out:
#    Number        Name Type_1  Type_2  Total  HP  Attack  Defense  Sp_Atk  \
# 0       1   Bulbasaur  Grass  Poison    318  45      49       49      65
# 1       2     Ivysaur  Grass  Poison    405  60      62       63      80
# 2       3    Venusaur  Grass  Poison    525  80      82       83     100
# 3       4  Charmander   Fire     NaN    309  39      52       43      60
# 4       5  Charmeleon   Fire     NaN    405  58      64       58      80
#
#    Sp_Def  ...  Color  hasGender  Pr_Male Egg_Group_1  Egg_Group_2  \
# 0      65  ...  Green       True    0.875     Monster        Grass
# 1      80  ...  Green       True    0.875     Monster        Grass
# 2     100  ...  Green       True    0.875     Monster        Grass
# 3      50  ...    Red       True    0.875     Monster       Dragon
# 4      65  ...    Red       True    0.875     Monster       Dragon
#
#    hasMegaEvolution Height_m Weight_kg  Catch_Rate      Body_Style
# 0             False     0.71       6.9          45       quadruped
# 1             False     0.99      13.0          45       quadruped
# 2              True     2.01     100.0          45       quadruped
# 3             False     0.61       8.5          45  bipedal_tailed
# 4             False     1.09      19.0          45  bipedal_tailed
#
# [5 rows x 23 columns]

# %%
from scipy.stats import itemfreq

df_pie = df[['Type_1', 'Attack', 'Defense', 'Speed', 'HP']].copy()

frequent_grp = itemfreq(df_pie.iloc[:,0])
frequent_grp = np.array(sorted(frequent_grp, key=lambda x: x[1]))[::-1][0:4,:]
print(frequent_grp)
# Out:
# [['Water' 105]
#  ['Normal' 93]
#  ['Grass' 66]
#  ['Bug' 63]]
# C:\Users\malla\anaconda3\lib\site-packages\ipykernel_launcher.py:5: DeprecationWarning: `itemfreq` is deprecated!
# `itemfreq` is deprecated and will be removed in a future version. Use instead `np.unique(..., return_counts=True)`
#   """

# %%
df_pie = df_pie[df_pie.loc[:,'Type_1'].str.contains(r'(Water|Normal|Grass|Bug)')]
# Names of the group
type_1_names = frequent_grp[:,0]
print(type_1_names)
df_grp = df_pie.groupby(['Type_1']).mean()
df_grp.iloc[0,:]
# Out:
# ['Water' 'Normal' 'Grass' 'Bug']
# C:\Users\malla\anaconda3\lib\site-packages\pandas\core\strings.py:1952: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.
#   return func(self, *args, **kwargs)
# Attack     65.222222
# Defense    67.698413
# Speed      60.063492
# HP         55.952381
# Name: Bug, dtype: float64

# %%
names = df_grp.columns
colors = ['gold', 'lightcoral', 
              'yellowgreen', 'lightskyblue']
explode = (0, 0, 0, 0.1)  # takes out only the 4th slice 
fig, [[ax1, ax2], [ax3, ax4]] = plt.subplots(nrows=2, ncols=2)
ax = [ax1, ax2, ax3, ax4]
for i in range(0,4):
    percent = df_grp.iloc[i,:]
    ax[i].pie(percent, explode = explode,
            labels = names, colors = colors,
            autopct='%.2f%%',   # display value
            shadow=True,
            startangle=90)
    ax[i].set_aspect('equal')
    ax[i].set_title(type_1_names[i])

plt.suptitle('Comparing major features of 4 most frequent Pokemon Group',fontsize = 11,fontweight = 'bold')
# Out:
# Text(0.5, 0.98, 'Comparing major features of 4 most frequent Pokemon Group')

# %% [markdown]
# ## Scatter Plot

# %%
tot_power = df.iloc[:,4]
print(tot_power.head(4))
catch_rate = df.iloc[:,21]
print(catch_rate.head(4))

fig,ax = plt.subplots(nrows=1,ncols=1)
p = ax.scatter(catch_rate,tot_power,c='g',label='Pokemons')
ax.grid()
ax.set_xlabel('Catch Rate')
ax.set_ylabel('Total Power')
ax.set_title('Pokemon Catch Rate vs their Power')
plt.legend([p],['Pokemons'])


### Matplotlib provides patches through which we can make an overwriting to highlight specified area on our previous plot
import matplotlib.patches as patches
import matplotlib.transforms as transforms

trans = transforms.blended_transform_factory(ax.transData,ax.transAxes)
rect = patches.Rectangle((44,0), width=2, height=5,
                         transform=trans, color='red',
                         alpha=0.4)
ax.add_patch(rect)
# Out:
# 0    318
# 1    405
# 2    525
# 3    309
# Name: Total, dtype: int64
# 0    45
# 1    45
# 2    45
# 3    45
# Name: Catch_Rate, dtype: int64

# %%
catch_rate_45 = df[df.loc[:,'Catch_Rate'] == 45]
pow_330 = catch_rate_45[catch_rate_45.loc[:,'Total'] <= 330]
print("Number of such Pokemons:", len(pow_330))
# Top 10 adamant Pokets
print(pow_330.loc[:,'Name'].head(10))
# Out:
# Number of such Pokemons: 29
# 0       Bulbasaur
# 3      Charmander
# 6        Squirtle
# 132         Eevee
# 146       Dratini
# 151     Chikorita
# 154     Cyndaquil
# 157      Totodile
# 224      Delibird
# 234      Smeargle
# Name: Name, dtype: object

# %% [markdown]
# #### Exercise

# %%
x, y, z = np.random.rand(3,50)

from mpl_toolkits import mplot3d
import numpy as np
import matplotlib.pyplot as plt
 
# Creating figure
fig = plt.figure(figsize = (10, 7))
ax = plt.axes(projection ="3d")
 
# Creating plot
ax.scatter3D(x, y, z, color = "green")
ax.set_xlabel("X Label")
ax.set_ylabel("Y Label")
ax.set_zlabel("Z Label")
plt.title("simple 3D scatter plot")

# show plot
plt.show()

# %% [markdown]
# ## Line Chart

# %%
bulbasaur = list(df.iloc[0,4:11])
charmander = list(df.iloc[3,4:11])
squirtle = list(df.iloc[6,4:11])
pokets = [bulbasaur, charmander, squirtle]

bul_hw = [df.iloc[0,19]*3.281, df.iloc[0,20]]
char_hw = [df.iloc[3,19]*3.281, df.iloc[3,20]]
squ_hw =  [df.iloc[6,19]*3.281, df.iloc[6,20]]
hw = [bul_hw, char_hw, squ_hw]

# %%
fig = plt.figure(0)
ax1 = plt.subplot2grid((4,3), (0,0), colspan=3)
ax1.plot(bulbasaur,'g--',bulbasaur,'go',label='Bulbasaur')
ax1.plot(charmander,'r--',charmander,'ro',label='Charmander')
ax1.plot(squirtle,'b--',squirtle,'bo',label='Squirtle')
ax1.set_xlim(-0.3,6.3)
ax1.grid()


text_x_coord = [0.045, .19, 0.34, 0.49, 0.64, 0.795, 0.945]
text_y_coord = [0.7, 0.57, 0.65, 0.75, 0.75, 0.75, 0.72]
rot = [0, 45, 45, 45, 45, 45, 45]
txt = [r'$T_{OTAL}$', r'$HP$', r'$A_{TTACK}$', r'$D_{EFENSE}$',
       r'$S_{P}\_A_{TK}$',r'$S_{P}\_D_{EF}$',r'$S_{PEED}$']


for i in range(0, 7):
    ax1.text(text_x_coord[i], text_y_coord[i], txt[i],
             transform = ax1.transAxes,  # makes width and height in percentage
             verticalalignment = 'top',
             rotation = rot[i],
             bbox = dict(
                     boxstyle = 'round',
                     facecolor = 'wheat',
                     alpha = 0.78))  # alpha -> transparency

#ax1.legend(bbox_to_anchor=(0.75,0.53, 0.5, 0.5))

# %% [markdown]
# ## Box Plot

# %%
ax2 = plt.subplot2grid((4,3), (1,0), colspan=1)
ax3 = plt.subplot2grid((4,3), (2,0), colspan=1)
ax4 = plt.subplot2grid((4,3), (3,0), colspan=1)
ax = [ax2, ax3, ax4]
colors = ['g', 'r', 'b']
for i in range(0, 3):
    bp = ax[i].boxplot(pokets[i][1:],patch_artist=True)
    # Adding colors to edges
    for element in ['boxes', 'whiskers', 'fliers', 'means', 'medians', 'caps']:
            plt.setp(bp[element], color='k')
    # Adding color inside the box
    for patch in bp['boxes']:
        patch.set(facecolor=colors[i])
    ax[i].set_ylim(35,70)  
    
ax3.annotate('Median', xy=(1.09, 51),xytext=(1.2, 60),
             arrowprops=dict(arrowstyle='fancy',facecolor='wheat'))
# Out:
# Text(1.2, 60, 'Median')

# %% [markdown]
# #### Exercise

# %%
x = np.arange(0.0, 5.0, 0.1)
y = np.cos(2 * np.pi * x) * np.exp(-x)

plt.figure(figsize=(10,10))
fig,ax = plt.subplots(1,1)
fig.suptitle("Main Heading")
ax.set_title("Figure Title")
ax.plot(x,y, marker='o', markerfacecolor='darkturquoise', alpha=0.75, markersize=6, color='k')
ax.set_xlabel("Abiscaa",fontdict={'color':'green'})
ax.set_ylabel("Ordinate",fontdict={'color':'green'})
ax.grid()
ax.text(1.1,0.4,r"$\theta=60^\degree$")
ax.annotate("2nd Crest",xy=(2,0.2),xytext=(2.5,0.3),arrowprops ={'arrowstyle':'fancy'})
# Out:
# Text(2.5, 0.3, '2nd Crest')

# %%
import numpy as np
x = np.array([1,1,1,1,2,3,4,4,4,4,3,2,1])
y = np.array([1,2,3,4,4,4,4,3,2,1,1,1,1])

plt.plot(x,y,color='w')
plt.text(1.02,3.5,"Text3\nnext line",rotation=45)
plt.text(3.9,2.25,"Text2",rotation=90)
plt.text(3.7,1.06,"Text1")
plt.xlim(1,4)
plt.ylim(1,4)
# Out:
# (1, 4)

# %% [markdown]
# ## Integrated Plots

# %%
bul_hw = [df.iloc[0,19]*3.281, df.iloc[0,20]]
char_hw = [df.iloc[3,19]*3.281, df.iloc[3,20]]
squ_hw =  [df.iloc[6,19]*3.281, df.iloc[6,20]]
hw = [bul_hw, char_hw, squ_hw]
colors = ['g', 'r', 'b']

ax5 = plt.subplot2grid((4,3), (1,1), colspan=2, rowspan = 3)
bar_width = 0.2
wdt = 0
names = ['Bulbasaur','Charmander','Squirtle']
for i in range(0, 3):
    p=ax5.barh(np.arange(2) + wdt, hw[i],bar_width,alpha = 0.5,color = colors[i],label = names[i])
    wdt += bar_width
    
ax5.legend(loc = 'lower right')
ax5.set_xlim(0,12)
ax5.set_ylim(-0.2,1.8)
plt.yticks(np.arange(2) + (bar_width)*1.5, 
           ('Height', 'Weight'))
# Out:
# ([<matplotlib.axis.YTick at 0x1af4d548588>,
#   <matplotlib.axis.YTick at 0x1af4d54eb08>],
#  <a list of 2 Text yticklabel objects>)
