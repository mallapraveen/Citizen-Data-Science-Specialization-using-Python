# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv(r"C:\Users\malla\OneDrive\Desktop\Citizen-Data-Science-Specialization-using-Python\Python for Data Science\Pandas\psps_data.csv")
df.head()
# Out:
#    Circuit  WindSustained  GustSustained   Thresholds    FPI  \
# 0   SONOMA           5.53           5.22  27.51/39.42   2.95
# 1    ANTON           1.33           6.06        31/46   3.23
# 2   SONOMA          21.00          39.50  27.51/39.42  12.94
# 3     PICK           1.83           5.17        31/46   2.62
# 4  Kuehner          19.60          45.50        31/46  12.91
#
#                              Reasons Month  pspsActivated
# 0                                NaN   DEC              0
# 1                                NaN   OCT              0
# 2  Exceeded Threshold - Exceeded FPI   DEC              1
# 3                                NaN   NOV              0
# 4     High Wind Trend - Exceeded FPI   DEC              1

# %%
df.sort_values("Circuit",ascending=False).head()
# Out:
#      Circuit  WindSustained  GustSustained Thresholds    FPI  \
# 913     ZONE           4.69           7.84      31/46   4.53
# 1121    ZONE          24.50          44.60      31/46  13.01
# 775     ZONE           3.20           1.67      31/46   4.18
# 243     ZONE          23.60          44.10      31/46  13.01
# 779     ZONE           4.79           7.06      31/46   1.82
#
#                              Reasons Month  pspsActivated
# 913                              NaN   DEC              0
# 1121  High Wind Trend - Exceeded FPI   NOV              1
# 775                              NaN   OCT              0
# 243   High Wind Trend - Exceeded FPI   NOV              1
# 779                              NaN   NOV              0

# %%
df.sort_values(["Circuit","GustSustained"],ascending=False).head()
# Out:
#      Circuit  WindSustained  GustSustained Thresholds    FPI  \
# 632     ZONE           23.0           46.7      31/46  12.50
# 588     ZONE           28.7           46.3      31/46  12.50
# 1121    ZONE           24.5           44.6      31/46  13.01
# 243     ZONE           23.6           44.1      31/46  13.01
# 303     ZONE           23.6           44.1      31/46  13.01
#
#                                 Reasons Month  pspsActivated
# 632   Exceeded Threshold - Exceeded FPI   OCT              1
# 588   Exceeded Threshold - Exceeded FPI   OCT              1
# 1121     High Wind Trend - Exceeded FPI   NOV              1
# 243      High Wind Trend - Exceeded FPI   NOV              1
# 303      High Wind Trend - Exceeded FPI   NOV              1

# %%
df.sort_values(["Circuit","GustSustained"],ascending=[True,False]).head()
# Out:
#      Circuit  WindSustained  GustSustained Thresholds    FPI  \
# 811   ACCENT          26.30          37.90      27/38  12.00
# 1119  ACCENT           1.44           6.31      27/38   6.25
# 1001  ACOSTA          34.63          67.81    31 / 46  12.56
# 349   ACOSTA          36.10          64.52    31 / 46  12.56
# 809   ACOSTA          29.56          61.16      31/46  13.92
#
#                                                 Reasons Month  pspsActivated
# 811                      High Wind Trend - Exceeded FPI   OCT              1
# 1119                                                NaN   OCT              0
# 1001  Exceeded Threshold - High Wind Trend - Exceede...   OCT              1
# 349   Exceeded Threshold - High Wind Trend - Exceede...   OCT              1
# 809                      High Wind Trend - Exceeded FPI   NOV              1

# %%
df.sort_values(["Circuit","GustSustained"],ascending=[True,False],inplace=True)

# %%
df.sort_index(ascending=True,inplace=True)
df
# Out:
#              Circuit  WindSustained  GustSustained   Thresholds    FPI  \
# 0             SONOMA           5.53           5.22  27.51/39.42   2.95
# 1              ANTON           1.33           6.06        31/46   3.23
# 2             SONOMA          21.00          39.50  27.51/39.42  12.94
# 3               PICK           1.83           5.17        31/46   2.62
# 4            Kuehner          19.60          45.50        31/46  12.91
# ...              ...            ...            ...          ...    ...
# 1143         FORTUNE           1.75           2.92        31/45   6.13
# 1144          SAVORY           4.39           0.21        29/42   2.25
# 1145         RAINBOW          26.50          34.70        31/46  13.01
# 1146  GRAPEVINE PEAK          19.00          24.00        31/46  12.70
# 1147           LOPEZ           1.16           1.72        31/46   1.04
#
#                                             Reasons Month  pspsActivated
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1148 entries, 0 to 1147
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Circuit        1148 non-null   object
#  1   WindSustained  1144 non-null   float64
#  2   GustSustained  1146 non-null   float64
#  3   Thresholds     1148 non-null   object
#  4   FPI            1142 non-null   float64
#  5   Reasons        574 non-null    object
#  6   Month          1148 non-null   object
#  7   pspsActivated  1148 non-null   int64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 80.7+ KB

# %%
df.dropna(subset=["Reasons","FPI","WindSustained"]).info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 564 entries, 2 to 1146
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Circuit        564 non-null    object
#  1   WindSustained  564 non-null    float64
#  2   GustSustained  564 non-null    float64
#  3   Thresholds     564 non-null    object
#  4   FPI            564 non-null    float64
#  5   Reasons        564 non-null    object
#  6   Month          564 non-null    object
#  7   pspsActivated  564 non-null    int64
# dtypes: float64(3), int64(1), object(4)
# memory usage: 39.7+ KB

# %%
print(type(df))
print(type(df["pspsActivated"]))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# <class 'pandas.core.series.Series'>

# %%
df["pspsActivated"] = df["pspsActivated"].astype(int)
df.head()
# Out:
#    Circuit  WindSustained  GustSustained   Thresholds    FPI  \
# 0   SONOMA           5.53           5.22  27.51/39.42   2.95
# 1    ANTON           1.33           6.06        31/46   3.23
# 2   SONOMA          21.00          39.50  27.51/39.42  12.94
# 3     PICK           1.83           5.17        31/46   2.62
# 4  Kuehner          19.60          45.50        31/46  12.91
#
#                              Reasons Month  pspsActivated
# 0                                NaN   DEC              0
# 1                                NaN   OCT              0
# 2  Exceeded Threshold - Exceeded FPI   DEC              1
# 3                                NaN   NOV              0
# 4     High Wind Trend - Exceeded FPI   DEC              1

# %%
df.nunique()
# Out:
# Circuit          212
# WindSustained    636
# GustSustained    658
# Thresholds        58
# FPI              523
# Reasons           17
# Month              4
# pspsActivated      2
# dtype: int64

# %%
df["Month"] = df["Month"].astype("category")
df["Reasons"] = df["Reasons"].astype("category")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1148 entries, 0 to 1147
# Data columns (total 8 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Circuit        1148 non-null   object
#  1   WindSustained  1144 non-null   float64
#  2   GustSustained  1146 non-null   float64
#  3   Thresholds     1148 non-null   object
#  4   FPI            1142 non-null   float64
#  5   Reasons        574 non-null    category
#  6   Month          1148 non-null   category
#  7   pspsActivated  1148 non-null   int32
# dtypes: category(2), float64(3), int32(1), object(2)
# memory usage: 52.6+ KB

# %%
df[["Month","Reasons"]]
# Out:
#      Month                                        Reasons
# 0      DEC                                            NaN
# 1      OCT                                            NaN
# 2      DEC              Exceeded Threshold - Exceeded FPI
# 3      NOV                                            NaN
# 4      DEC                 High Wind Trend - Exceeded FPI
# ...    ...                                            ...
# 1143   OCT                                            NaN
# 1144   OCT                                            NaN
# 1145   NOV                 High Wind Trend - Exceeded FPI
# 1146   OCT  Preemptive: To coordinate with PG&E resources
# 1147   OCT                                            NaN
#
# [1148 rows x 2 columns]

# %%
df.reset_index(inplace=True)
df
# Out:
#       index         Circuit  WindSustained  GustSustained   Thresholds    FPI  \
# 0         0          SONOMA           5.53           5.22  27.51/39.42   2.95
# 1         1           ANTON           1.33           6.06        31/46   3.23
# 2         2          SONOMA          21.00          39.50  27.51/39.42  12.94
# 3         3            PICK           1.83           5.17        31/46   2.62
# 4         4         Kuehner          19.60          45.50        31/46  12.91
# ...     ...             ...            ...            ...          ...    ...
# 1143   1143         FORTUNE           1.75           2.92        31/45   6.13
# 1144   1144          SAVORY           4.39           0.21        29/42   2.25
# 1145   1145         RAINBOW          26.50          34.70        31/46  13.01
# 1146   1146  GRAPEVINE PEAK          19.00          24.00        31/46  12.70
# 1147   1147           LOPEZ           1.16           1.72        31/46   1.04
#
# ...

# %%
df.set_index("Circuit",inplace=True)
df
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-32-4a70e94e457e> in <module>
# ----> 1 df.set_index("Circuit",inplace=True)
#       2 df
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in set_index(self, keys, drop, append, inplace, verify_integrity)
#    4301
#    4302         if missing:
# -> 4303             raise KeyError(f"None of {missing} are in the columns")
#    4304
#    4305         if inplace:
#
# KeyError: "None of ['Circuit'] are in the columns"

# %%
df.sort_index(inplace=True)
df
# Out:
#          index  WindSustained  GustSustained Thresholds    FPI  \
# Circuit
# ACCENT     811          26.30          37.90      27/38  12.00
# ACCENT    1119           1.44           6.31      27/38   6.25
# ACOSTA     736           1.63           6.91      31/46   1.50
# ACOSTA     221          23.40          46.10      31/46  13.80
# ACOSTA     876           2.99           5.69      31/46   3.76
# ...        ...            ...            ...        ...    ...
# ZONE       821           2.80           1.55      31/46   6.24
# ZONE       243          23.60          44.10      31/46  13.01
# ZONE       588          28.70          46.30      31/46  12.50
# ZONE       490           3.31           6.41      31/46   5.23
# ZONE       622          23.90          41.60      31/46  12.95
#
#                                    Reasons Month  pspsActivated
# Circuit
# ACCENT      High Wind Trend - Exceeded FPI   OCT              1
# ...

# %%
print(df.nunique())
print("\n")
print(df["Circuit"].value_counts().size)
print("\n")
print(df["Circuit"].value_counts())
# Out:
# Circuit          212
# WindSustained    636
# GustSustained    658
# Thresholds        58
# FPI              523
# Reasons           17
# Month              4
# pspsActivated      2
# dtype: int64
#
#
# 212
#
#
# ENERGY         36
# ANTON          32
# SAND CANYON    30
# DAVENPORT      24
# SHOVEL         20
#                ..
# BENCH           2
# GLASSCOCK       2
# VIDEO           2
# CARMELITA       2
# RANKIN          2
# Name: Circuit, Length: 212, dtype: int64

# %%
df["Circuit"].value_counts(normalize=True)*100  ### in percent
# Out:
# ENERGY         3.135889
# ANTON          2.787456
# SAND CANYON    2.613240
# DAVENPORT      2.090592
# SHOVEL         1.742160
#                  ...
# BENCH          0.174216
# GLASSCOCK      0.174216
# VIDEO          0.174216
# CARMELITA      0.174216
# RANKIN         0.174216
# Name: Circuit, Length: 212, dtype: float64

# %%
print(df['Circuit'])
print("\n")
print(df.loc[1])
# Out:
# 0               SONOMA
# 1                ANTON
# 2               SONOMA
# 3                 PICK
# 4              Kuehner
#              ...
# 1143           FORTUNE
# 1144            SAVORY
# 1145           RAINBOW
# 1146    GRAPEVINE PEAK
# 1147             LOPEZ
# Name: Circuit, Length: 1148, dtype: object
#
#
# Circuit          ANTON
# WindSustained     1.33
# GustSustained     6.06
# Thresholds       31/46
# FPI               3.23
# Reasons            NaN
# Month              OCT
# pspsActivated        0
# Name: 1, dtype: object

# %%
df.loc[0]["FPI"]
# Out:
# 2.95

# %%
df.loc[0,"FPI"]
# Out:
# 2.95

# %%
print(df.set_index("Circuit").loc["SONOMA"])
print("\n")
print(df.set_index("Circuit").iloc[0])
# Out:
#          WindSustained  GustSustained   Thresholds    FPI  \
# Circuit
# SONOMA            5.53           5.22  27.51/39.42   2.95
# SONOMA           21.00          39.50  27.51/39.42  12.94
# SONOMA           27.90          44.10        28/39  13.00
# SONOMA            1.01           5.60        28/39   2.94
#
#                                    Reasons Month  pspsActivated
# Circuit
# SONOMA                                 NaN   DEC              0
# SONOMA   Exceeded Threshold - Exceeded FPI   DEC              1
# SONOMA   Exceeded Threshold - Exceeded FPI   NOV              1
# SONOMA                                 NaN   NOV              0
#
#
# WindSustained           5.53
# GustSustained           5.22
# Thresholds       27.51/39.42
# FPI                     2.95
# Reasons                  NaN
# Month                    DEC
# pspsActivated              0
# Name: SONOMA, dtype: object

# %%
print(df.set_index("Circuit").loc["SONOMA","FPI"])
df.set_index("Circuit").loc["SONOMA"]["FPI"]
# Out:
# Circuit
# SONOMA     2.95
# SONOMA    12.94
# SONOMA    13.00
# SONOMA     2.94
# Name: FPI, dtype: float64
# Circuit
# SONOMA     2.95
# SONOMA    12.94
# SONOMA    13.00
# SONOMA     2.94
# Name: FPI, dtype: float64

# %%
print(df.set_index("Circuit").loc[["SONOMA","EVERETT"]][["FPI","pspsActivated"]])
df.set_index("Circuit").loc[["SONOMA","EVERETT"],["FPI","pspsActivated"]]
# Out:
#            FPI  pspsActivated
# Circuit
# SONOMA    2.95              0
# SONOMA   12.94              1
# SONOMA   13.00              1
# SONOMA    2.94              0
# EVERETT   3.21              0
# EVERETT  12.10              1
#            FPI  pspsActivated
# Circuit
# SONOMA    2.95              0
# SONOMA   12.94              1
# SONOMA   13.00              1
# SONOMA    2.94              0
# EVERETT   3.21              0
# EVERETT  12.10              1

# %%
df.iloc[0][0]
df.iloc[0][0]
# Out:
# 5.53

# %%
df.iloc[0][7]
# Out:
# 0

# %%
df.iloc[0,7]
# Out:
# 0

# %%
df.iloc[0]
# Out:
# Circuit               SONOMA
# WindSustained           5.53
# GustSustained           5.22
# Thresholds       27.51/39.42
# FPI                     2.95
# Reasons                  NaN
# Month                    DEC
# pspsActivated              0
# Name: 0, dtype: object

# %%
df["Circuit"] == "SONOMA"
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 1143    False
# 1144    False
# 1145    False
# 1146    False
# 1147    False
# Name: Circuit, Length: 1148, dtype: bool

# %%
df[df["Circuit"] == "SONOMA"]
# Out:
#     Circuit  WindSustained  GustSustained   Thresholds    FPI  \
# 0    SONOMA           5.53           5.22  27.51/39.42   2.95
# 2    SONOMA          21.00          39.50  27.51/39.42  12.94
# 379  SONOMA          27.90          44.10        28/39  13.00
# 804  SONOMA           1.01           5.60        28/39   2.94
#
#                                Reasons Month  pspsActivated
# 0                                  NaN   DEC              0
# 2    Exceeded Threshold - Exceeded FPI   DEC              1
# 379  Exceeded Threshold - Exceeded FPI   NOV              1
# 804                                NaN   NOV              0

# %%
df[(df["Circuit"] == "SONOMA") & (df["pspsActivated"] == 0)]
# Out:
#     Circuit  WindSustained  GustSustained   Thresholds   FPI Reasons Month  \
# 0    SONOMA           5.53           5.22  27.51/39.42  2.95     NaN   DEC
# 804  SONOMA           1.01           5.60        28/39  2.94     NaN   NOV
#
#      pspsActivated
# 0                0
# 804              0

# %%
df[(df["GustSustained"]>40) & (df["WindSustained"]>20)]
# Out:
#                      Circuit  WindSustained  GustSustained Thresholds    FPI  \
# 7                   CALGROVE          29.50           45.7      31/46  12.70
# 9     High Wind Trend SKI HI          21.50           40.4      31/46  12.53
# 12                      NAPA          28.60           40.9      28/39  12.00
# 15                      TAPO          28.20           46.3      31/46  13.03
# 16                  CUTHBERT          27.90           47.5      31/46  12.00
# ...                      ...            ...            ...        ...    ...
# 1131              WHITECLIFF          34.20           48.0      31/46  12.42
# 1132                AMETHYST          30.94           51.0    31 / 46  12.55
# 1135                BIG ROCK          29.80           43.3      31/46  12.00
# 1138                 TAGGERT          34.60           49.0      31/46  12.32
# 1142                  IMPALA          25.70           57.4      31/46  12.78
#
# ...

# %%
df[df["GustSustained"].between(20,30)]
# Out:
#              Circuit  WindSustained  GustSustained Thresholds    FPI  \
# 104            STEEL           7.90          28.80      30/43  13.00
# 800           GILMAN           7.90          28.80      31/45  13.02
# 906      BEAR VALLEY           8.94          29.88    18 / 29  13.24
# 933           FROZEN          19.00          24.00      31/46  12.70
# 1060     BEAR VALLEY          13.48          29.00    18 / 29  13.24
# 1146  GRAPEVINE PEAK          19.00          24.00      31/46  12.70
#
#                                                 Reasons Month  pspsActivated
# 104                      High Wind Trend - Exceeded FPI   NOV              1
# 800                      High Wind Trend - Exceeded FPI   NOV              1
# 906   Exceeded Threshold - High Wind Trend - Exceede...   OCT              1
# 933       Preemptive: To coordinate with PG&E resources   OCT              1
# 1060  Exceeded Threshold - High Wind Trend - Exceede...   OCT              1
# ...

# %%
df["GustSustained"].mean()
# Out:
# 25.112260034904036

# %%
df["GustSustained"].mode()
# Out:
# 0    46.3
# dtype: float64

# %%
df["GustSustained"].var()
# Out:
# 478.9620571585233

# %%
df["GustSustained"].std()
# Out:
# 21.88520178473398

# %%
df["GustSustained"].sum()
# Out:
# 28778.649999999998

# %%
df["GustSustained"].max()
# Out:
# 96.2

# %%
df.groupby("Circuit")

# %%
df_grp = df.groupby("Circuit")
df_grp["WindSustained"].max()
# Out:
# Circuit
# ACCENT        26.30
# ACOSTA        36.10
# ALOLA #2      13.90
# AMBERCREST    29.50
# AMETHYST      30.94
#               ...
# WHITECLIFF    34.20
# WINERY        21.30
# WOBEGONE      25.10
# ZENDA         23.50
# ZONE          28.70
# Name: WindSustained, Length: 212, dtype: float64

# %%
df_grp["WindSustained"].max().sort_values(ascending=False)
# Out:
# Circuit
# FERRARA        170.02
# SAND            64.87
# CANYONSAND      57.88
# RED BOX         54.00
# ARROWHEAD       51.30
#                 ...
# ALOLA #2        13.90
# BEAR VALLEY     13.48
# THACHER         12.60
# GRAPEVINE        9.00
# COOLER           2.38
# Name: WindSustained, Length: 212, dtype: float64

# %% [markdown]
# ## Melting

# %%
df.melt(id_vars = ["Circuit","FPI"]
       ,value_vars = ["WindSustained","GustSustained"])
# Out:
#              Circuit    FPI       variable  value
# 0             SONOMA   2.95  WindSustained   5.53
# 1              ANTON   3.23  WindSustained   1.33
# 2             SONOMA  12.94  WindSustained  21.00
# 3               PICK   2.62  WindSustained   1.83
# 4            Kuehner  12.91  WindSustained  19.60
# ...              ...    ...            ...    ...
# 2291         FORTUNE   6.13  GustSustained   2.92
# 2292          SAVORY   2.25  GustSustained   0.21
# 2293         RAINBOW  13.01  GustSustained  34.70
# 2294  GRAPEVINE PEAK  12.70  GustSustained  24.00
# 2295           LOPEZ   1.04  GustSustained   1.72
#
# [2296 rows x 4 columns]

# %%
df.melt(id_vars = ["Circuit","FPI"]
       ,value_vars = ["WindSustained","GustSustained"],
       var_name = "Wind/Gust",
       value_name = "Value")
# Out:
#              Circuit    FPI      Wind/Gust  Value
# 0             SONOMA   2.95  WindSustained   5.53
# 1              ANTON   3.23  WindSustained   1.33
# 2             SONOMA  12.94  WindSustained  21.00
# 3               PICK   2.62  WindSustained   1.83
# 4            Kuehner  12.91  WindSustained  19.60
# ...              ...    ...            ...    ...
# 2291         FORTUNE   6.13  GustSustained   2.92
# 2292          SAVORY   2.25  GustSustained   0.21
# 2293         RAINBOW  13.01  GustSustained  34.70
# 2294  GRAPEVINE PEAK  12.70  GustSustained  24.00
# 2295           LOPEZ   1.04  GustSustained   1.72
#
# [2296 rows x 4 columns]
